# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
# load dataset from sklearn 


url = "https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv"
boston = pd.read_csv(url)
print(boston.head())
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df1 = pd.read_csv(url)
df1.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df1= df1.drop("medv", axis=1)

# %%
df= boston

# %%
df.rename(columns={"medv":"Price"},inplace=True)

# %%
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  Price
# 0  396.90   4.98   24.0
# 1  396.90   9.14   21.6
# 2  392.83   4.03   34.7
# 3  394.63   2.94   33.4
# 4  396.90   5.33   36.2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  Price    506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
## summarizing the sats of the data 
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
### check the missing value 
df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# Price      0
# dtype: int64

# %%
## exploratory data analysis 
df.corr()
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
import seaborn as sns 
sns.pairplot(df)

# %% [markdown]
# ## Analyzing The Correlated Features

# %%
plt.scatter(df["crim"],df["Price"])
plt.xlabel("crime")
plt.ylabel("price")
# Out:
# Text(0, 0.5, 'price')

# %%
plt.scatter(df['rm'],df['Price'])
plt.xlabel("rm")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
sns.regplot(x="rm",y="Price",data=df)
# Out:
# <Axes: xlabel='rm', ylabel='Price'>

# %%
sns.regplot(x="lstat",y="Price",data=df)
# Out:
# <Axes: xlabel='lstat', ylabel='Price'>

# %%
sns.regplot(x="chas",y="Price",data=df)
# Out:
# <Axes: xlabel='chas', ylabel='Price'>

# %%
sns.regplot(x="ptratio",y="Price",data=df)
# Out:
# <Axes: xlabel='ptratio', ylabel='Price'>

# %%
X= df.iloc[:,:-1]
X.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 4  396.90   5.33

# %%
y= df.iloc[:,-1]
y.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: Price, dtype: float64

# %%
## train test split 
from sklearn.model_selection import train_test_split
X_train,X_test,y_train ,y_test = train_test_split(X,y ,test_size= 0.30 ,random_state=42)

# %%
X_train.head()
# Out:
#          crim   zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 5     0.02985  0.0   2.18     0  0.458  6.430  58.7  6.0622    3  222
# 116   0.13158  0.0  10.01     0  0.547  6.176  72.5  2.7301    6  432
# 45    0.17142  0.0   6.91     0  0.448  5.682  33.8  5.1004    3  233
# 16    1.05393  0.0   8.14     0  0.538  5.935  29.3  4.4986    4  307
# 468  15.57570  0.0  18.10     0  0.580  5.926  71.0  2.9084   24  666
#
#      ptratio       b  lstat
# 5       18.7  394.12   5.21
# 116     17.8  393.30  12.04
# 45      17.9  396.90  10.21
# 16      21.0  386.85   6.58
# 468     20.2  368.74  18.13

# %% [markdown]
# ## Standardize the dataset

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
import pickle 
pickle.dump(scaler,open('scaling.pkl','wb'))

# %% [markdown]
# ## Model training

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
## print the coefficient 
regression.coef_
# Out:
# array([-1.10834602,  0.80843998,  0.34313466,  0.81386426, -1.79804295,
#         2.913858  , -0.29893918, -2.94251148,  2.09419303, -1.44706731,
#        -2.05232232,  1.02375187, -3.88579002])

# %%
regression.intercept_
# Out:
# np.float64(23.01581920903955)

# %%
regression.get_params()
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'positive': False,
#  'tol': 1e-06}

# %%
## prediction with test data

# %%
y_pred = regression.predict(X_test)

# %%
## plot a sctter plot 
plt.scatter(y_test,y_pred)

# %%
## Residuals
residuals=y_test-y_pred

# %%
sns.displot(residuals,kind="kde")

# %%
## scatter plot 
plt.scatter(y_test,residuals)

# %% [markdown]
# ## R square and adjusted R square

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

print(mean_absolute_error(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# 3.1627098714574053
# 21.517444231177205
# 4.6386899261728205

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
print(score)
# Out:
# 0.7112260057484934

# %%
#display adjusted R-squared
1 - (1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.6840226584639312

# %% [markdown]
# ## New Data Prediction

# %% [markdown]
# To convert a pandas DataFrame to a NumPy array, you can use:
# 1. values (older method, still used)
#
#      array = df.values
# 2. .to_numpy() (recommended, safer)
#
#       array = df.to_numpy()

# %%
df1.iloc[0, :]
# Out:
# crim         0.00632
# zn          18.00000
# indus        2.31000
# chas         0.00000
# nox          0.53800
# rm           6.57500
# age         65.20000
# dis          4.09000
# rad          1.00000
# tax        296.00000
# ptratio     15.30000
# b          396.90000
# lstat        4.98000
# Name: 0, dtype: float64

# %%
df1.iloc[0, :].values.reshape(1, -1)
# Out:
# array([[6.320e-03, 1.800e+01, 2.310e+00, 0.000e+00, 5.380e-01, 6.575e+00,
#         6.520e+01, 4.090e+00, 1.000e+00, 2.960e+02, 1.530e+01, 3.969e+02,
#         4.980e+00]])

# %%
scaler.transform(df1.iloc[0, :].values.reshape(1, -1))
# Out:
# d:\python\venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-0.41709233,  0.29216419, -1.27338003, -0.28154625, -0.16513629,
#          0.34715902, -0.13030059,  0.15267164, -0.97798895, -0.66777595,
#         -1.32142483,  0.42854113, -1.04769976]])

# %%
regression.predict(scaler.transform(df1.iloc[0, :].values.reshape(1, -1)))
# Out:
# d:\python\venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([30.08649576])

# %% [markdown]
# Pickling The Model file For Deployment

# %%
import pickle

# %%
pickle.dump(regression,open('regression.pkl',"wb"))

# %%
pickled_model=pickle.load(open("regression.pkl","rb"))

# %%
pickled_model.predict(scaler.transform(df1.iloc[0, :].values.reshape(1, -1)))
# Out:
# d:\python\venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([30.08649576])
